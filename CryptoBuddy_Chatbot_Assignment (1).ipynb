# %% [markdown]
# # 💰 CryptoBuddy: Your First AI-Powered Financial Sidekick!
# Welcome to **CryptoBuddy**, your friendly chatbot that helps you explore cryptocurrency trends and sustainability.

# %%
# Step 1: Predefined Crypto Data
crypto_db = {
    "Bitcoin": {
        "price_trend": "rising",
        "market_cap": "high",
        "energy_use": "high",
        "sustainability_score": 3
    },
    "Ethereum": {
        "price_trend": "stable",
        "market_cap": "high",
        "energy_use": "medium",
        "sustainability_score": 6
    },
    "Cardano": {
        "price_trend": "rising",
        "market_cap": "medium",
        "energy_use": "low",
        "sustainability_score": 8
    }
}

# %%
# Step 2: Chatbot Logic and Functions

def greet_user():
    print("👋 Hey there! I’m *CryptoBuddy*, your AI-powered crypto sidekick!")
    print("Ask me things like:")
    print("- Which crypto is trending up?")
    print("- What’s the most sustainable coin?")
    print("- Tell me about Bitcoin\n")

def get_user_input():
    return input("💬 You: ").lower()

def process_input(user_input):
    if "trending" in user_input or "rising" in user_input:
        trending_cryptos = [name for name, data in crypto_db.items() if data["price_trend"] == "rising"]
        return f"📈 These cryptos are currently trending up: {', '.join(trending_cryptos)}"

    elif "sustainable" in user_input or "most green" in user_input:
        most_sustainable = max(crypto_db.items(), key=lambda x: x[1]["sustainability_score"])
        return f"🌱 The most sustainable coin is *{most_sustainable[0]}* with a score of {most_sustainable[1]['sustainability_score']}/10."

    elif "bitcoin" in user_input:
        data = crypto_db["Bitcoin"]
        return format_crypto_data("Bitcoin", data)

    elif "ethereum" in user_input:
        data = crypto_db["Ethereum"]
        return format_crypto_data("Ethereum", data)

    elif "cardano" in user_input:
        data = crypto_db["Cardano"]
        return format_crypto_data("Cardano", data)

    elif "bye" in user_input or "exit" in user_input:
        return "👋 Bye! Remember, always do your own research before investing. Stay crypto-curious! 🚀"

    else:
        return "🤖 Hmm... I didn’t get that. Try asking about trends, sustainability, or a specific coin."

def format_crypto_data(name, data):
    return (f"📊 Here’s the scoop on *{name}*:\n"
            f"- Price Trend: {data['price_trend'].capitalize()}\n"
            f"- Market Cap: {data['market_cap'].capitalize()}\n"
            f"- Energy Use: {data['energy_use'].capitalize()}\n"
            f"- Sustainability Score: {data['sustainability_score']}/10")

def run_chatbot():
    greet_user()
    while True:
        user_input = get_user_input()
        response = process_input(user_input)
        print(f"🤖 CryptoBuddy: {response}")
        if "bye" in user_input or "exit" in user_input:
            break

# %%
# Step 3: Run the Chatbot
run_chatbot()

# %% [markdown]
# ## ✅ Step 5: Test Your Bot
#
# ### Sample Conversation
#
# ```
# 💬 You: Which crypto should I buy for long-term growth?
# 🤖 CryptoBuddy: Cardano (ADA) is trending up and has a top-tier sustainability score! 🚀
#
# 💬 You: Tell me about Ethereum
# 🤖 CryptoBuddy:
# 📊 Here’s the scoop on *Ethereum*:
# - Price Trend: Stable
# - Market Cap: High
# - Energy Use: Medium
# - Sustainability Score: 6/10
#
# 💬 You: What’s the most sustainable coin?
# 🤖 CryptoBuddy: 🌱 The most sustainable coin is *Cardano* with a score of 8/10.
#
# 💬 You: bye
# 🤖 CryptoBuddy: 👋 Bye! Remember, always do your own research before investing. Stay crypto-curious! 🚀
# ```

# %% [markdown]
# ## 🧠 Stretch Goals & Ethics Alert
#
# - **Ethics Disclaimer**
# ⚠️ *Crypto is risky—always do your own research before investing!*
#
# - **Stretch Goals**
#   - 🔄 Use [CoinGecko API](https://www.coingecko.com/en/api) to fetch real-time prices.
#   - 🧠 Add basic NLP using `nltk` for more natural queries.
#   - 💻 Build a GUI using `tkinter` or a chatbot web interface with `Flask`.

# %% [markdown]
# ## 📘 Summary Prompt
#
# **Write a 50-word summary:**
# *How does this chatbot mimic basic AI decision-making?*
#
# ➡️ _Hint: It uses rule-based logic to simulate intelligent behavior using conditions on crypto trends and sustainability, mimicking decision-making by selecting the best options based on user questions._
